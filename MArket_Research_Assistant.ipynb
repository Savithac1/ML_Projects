# %% [markdown]
# ## **Market Research Assistant**

# %% [markdown]
# # Abstract
# This project develops an AI-powered market research assistant that generates concise industry reports based on Wikipedia data. Designed for business analysts in large corporations, the assistant automates information retrieval and report generation, reducing manual effort in market research.
#
# # Objective
# To create an automated system that fetches and summarizes industry-specific information from Wikipedia, structuring the output in a standardized JSON format.
#
# # Problem Statement
# Market research is time-intensive, requiring analysts to sift through vast amounts of data to extract relevant insights. This project addresses this challenge by leveraging natural language processing (NLP) and retrieval-based AI to generate structured reports, including industry overviews, key players, market trends, and relevant sources.
#
# # Key Features
#
# Wikipedia-based industry research retrieval
#
# JSON-formatted structured output
#
# Automated summarization of key industry insights
#
# Performance optimization techniques for improved accuracy
#
# This implementation leverages LangChain and WikipediaRetriever to streamline report generation. Future improvements may include refining prompt engineering, integrating multiple data sources, and enhancing retrieval accuracy.

# %%
# !pip install google-generativeai
# !pip install wikipedia
# Out:
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.11/dist-packages (0.8.4)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.24.1)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.160.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.27.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (4.25.6)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.10.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (4.12.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core->google-generativeai) (1.68.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.11/dist-packages (from google-api-core->google-generativeai) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (4.9)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai) (4.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic->google-generativeai) (2.27.2)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.70.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.62.3)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2025.1.31)
# Requirement already satisfied: wikipedia in /usr/local/lib/python3.11/dist-packages (1.4.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from wikipedia) (4.13.3)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wikipedia) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2025.1.31)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->wikipedia) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->wikipedia) (4.12.2)

# %%
# !pip install google-generativeai wikipedia langchain fpdf

import google.generativeai as genai
import wikipedia
import json
import os
import re
from langchain.prompts import PromptTemplate
from functools import lru_cache
from fpdf import FPDF

genai.configure(api_key=os.getenv("GEMINI_API_KEY", "AI**"))


system_prompt_template = PromptTemplate.from_template("""
You are an AI research assistant for a business analyst conducting market research on various industries.
Your task is to generate a **detailed and structured** industry report **in JSON format** based **ONLY** on the Wikipedia data provided.
Pay special attention to capturing detailed information on:
- Challenges, risks, and barriers faced by the industry.
- Market size, growth trends, and any numerical data available.
- Detailed information on major companies, including historical context and notable events (e.g., acquisitions).

Please ensure that the descriptions in the "Market Size and Growth Potential" section are as long and descriptive as possible, and include all available details from the source.

### **Report Structure**
{
  "Industry Overview": {
    "Significance": "<Explain the industry's significance and economic role>",
    "Historical Development": "<Discuss historical development and transformation over time>",
    "Global Differences": "<Provide insights into global vs. regional differences>"
  },
  "Key Trends": [
    {
      "Trend": "<Trend name>",
      "Description": "<Trend description>"
    },
    ... (at least 2-4 items)
  ],
  "Challenges": {
    "Risks And Barriers": "<Identify key risks and barriers (economic, regulatory, operational)>",
    "Addressing Issues": "<Describe how companies are addressing these issues>"
  },
  "Market Size and Growth Potential": {
    "Market Size": "<Provide a detailed description including any numerical data available>",
    "Growth Trends": "<Provide a detailed analysis of historical growth trends and future projections>"
  },
  "Major Companies": {
    "companies": [
      "<List 2-5 leading companies along with a brief note on their market influence, innovations, and historical context>"
    ]
  },
  "Conclusion": {
    "Industry Outlook": "<Summarize the industry outlook>",
    "Future Opportunities": "<Highlight future opportunities and key developments>"
  }
}

### **Important Rules**
- Remove any section with no meaningful data.
- The final report must be **less than 600 words**.
- Ensure structured JSON output enclosed in triple backticks with the label 'json'.
- Do NOT generate new facts beyond the Wikipedia content.
""")



@lru_cache(maxsize=32)
def get_wikipedia_content(industry):
    """
    Retrieves the full Wikipedia page content and URL for the given industry.
    If the direct query fails or is ambiguous, it tries alternative queries
    (appending 'industry' if necessary, and finally using Wikipedia's search function).
    Uses caching to avoid duplicate requests.
    """
    try:

        page = wikipedia.page(industry)
    except (wikipedia.exceptions.PageError, wikipedia.exceptions.DisambiguationError):
        alt_query = industry
        if "industry" not in industry.lower():
            alt_query = industry + " industry"
        try:
            page = wikipedia.page(alt_query)
        except (wikipedia.exceptions.PageError, wikipedia.exceptions.DisambiguationError):
            search_results = wikipedia.search(industry)
            if search_results:
                try:
                    page = wikipedia.page(search_results[0])
                except Exception as e:
                    raise ValueError(f"Unable to retrieve a page for '{industry}' using search results: {e}")
            else:
                raise ValueError(f"No Wikipedia page found for '{industry}'.")
    return page.content, page.url

def extract_json_block(text):
    """
    Uses regex to extract a JSON block enclosed in triple backticks with the 'json' label.
    """
    json_pattern = r"```json\s*(\{.*?\})\s*```"
    match = re.search(json_pattern, text, re.DOTALL)
    if match:
        json_str = match.group(1)
        try:
            return json.loads(json_str)
        except json.JSONDecodeError as e:
            raise ValueError(f"JSON parsing failed: {str(e)}")
    else:
        raise ValueError("No JSON block found in the model output.")

def extract_additional_info(wiki_text, keywords):
    """
    Extracts additional information from the Wikipedia text based on provided keywords.
    Returns concatenated sentences containing those keywords.
    """
    sentences = wiki_text.split('.')
    relevant = [s.strip() for s in sentences if any(kw.lower() in s.lower() for kw in keywords)]
    return ". ".join(relevant) + "."

def merge_additional_info(report_json, wiki_text):
    """
    Merges additional extracted information about challenges and market data into the report JSON.
    """
    # Define keywords for challenges and market size.
    challenge_keywords = ["challenge", "risk", "barrier", "obstacle", "problem"]
    market_keywords = ["market size", "growth", "share", "projection", "trend", "dollar", "billion"]

    # Extract additional info.
    extra_challenges = extract_additional_info(wiki_text, challenge_keywords)
    extra_market = extract_additional_info(wiki_text, market_keywords)

    # Merge if the fields are empty or lack detail.
    if not report_json.get("Challenges", {}).get("Risks And Barriers"):
        report_json.setdefault("Challenges", {})["Risks And Barriers"] = extra_challenges
    if not report_json.get("Market Size and Growth Potential", {}).get("Market Size"):
        report_json.setdefault("Market Size and Growth Potential", {})["Market Size"] = extra_market

    return report_json

def clean_text(text):
    """
    Cleans the text by removing specific patterns like numeric ranges with Unicode dashes.
    """
    # Remove patterns like "1974–1984" (digits, en-dash, digits)
    cleaned = re.sub(r'\d+–\d+', '', text)
    return cleaned.strip()

def clean_report(report):
    """
    Recursively cleans all string fields in the report dictionary.
    """
    if isinstance(report, dict):
        return {k: clean_report(v) for k, v in report.items()}
    elif isinstance(report, list):
        return [clean_report(item) for item in report]
    elif isinstance(report, str):
        return clean_text(report)
    else:
        return report

def generate_market_report_gemini(industry):
    """
    Generates a comprehensive market research report for the given industry.
    Combines full Wikipedia data with a detailed prompt and uses Gemini 1.5 Flash.
    Returns a structured JSON report.
    """
    try:
        wiki_content, wiki_url = get_wikipedia_content(industry)
    except ValueError as err:
        return {"error": str(err)}

    # Assemble the final prompt by combining the system prompt with the full Wikipedia data.
    final_prompt = system_prompt_template.template + "\n\nWikipedia Data:\n" + wiki_content

    # Use Gemini 1.5 Flash for content generation.
    model = genai.GenerativeModel("gemini-1.5-flash")
    response = model.generate_content([final_prompt])
    full_text = response.text.strip()

    try:
        report_json = extract_json_block(full_text)
    except ValueError as e:
        return {"error": str(e), "raw_output": full_text}

    # Merge in additional extracted info (e.g., challenges, market data).
    report_json = merge_additional_info(report_json, wiki_content)

    # Add metadata if missing.
    report_json["source_url"] = wiki_url
    report_json["industry"] = industry

    # Clean all text in the report to remove undesired patterns.
    report_json = clean_report(report_json)

    return report_json

# Step 5: Generate reports for multiple industries.
industries = [
    "Aluminium",
    "Advertising",
    "Internet Services",
    "Automobile Manufacturers",
    "Automobile Manufacturers in South Korea"
]
all_reports = {ind: generate_market_report_gemini(ind) for ind in industries}

# Convert the reports dictionary into a formatted JSON string.
json_string = json.dumps(all_reports, indent=4, ensure_ascii=False)

# %%
# --- PDF Generation Section ---
from fpdf import FPDF

class PDF(FPDF):
    # Remove the footer if you don't want any page numbers.
    def footer(self):
        pass

pdf = PDF()
pdf.add_page()
pdf.set_auto_page_break(auto=True, margin=15)
# Use a monospaced font (Courier) for better JSON readability.
pdf.set_font("Courier", size=10)

# Convert your JSON reports dictionary into a formatted string.
json_string = json.dumps(all_reports, indent=4, ensure_ascii=False)
# Replace problematic Unicode characters if needed.
safe_string = json_string.replace("\u2013", "-").encode("latin-1", "replace").decode("latin-1")



# Optionally, you can remove any unwanted page markers from the safe_string.
# For example, if your JSON accidentally contains "Page X", you can remove it:
safe_string = re.sub(r'Page\s+\d+', '', safe_string)

# Add the JSON string to the PDF.
pdf.multi_cell(0, 5, safe_string)

pdf_file = "Q9_MSIN0231.pdf"
pdf.output(pdf_file)

print(f"All detailed reports have been saved to '{pdf_file}'.")
# Out:
# All detailed reports have been saved to 'Q9_MSIN0231.pdf'.

# %%
# Additional Industry reports for testing purposes

# !pip install google-generativeai wikipedia langchain fpdf

import google.generativeai as genai
import wikipedia
import json
import os
import re
from langchain.prompts import PromptTemplate
from functools import lru_cache

# Configure your Gemini API key securely.
genai.configure(api_key=os.getenv("GEMINI_API_KEY", "AI****"))

# Define the system prompt template
system_prompt_template = PromptTemplate.from_template("""
You are an AI research assistant for a business analyst conducting market research on various industries.
Your task is to generate a **detailed and structured** industry report **in JSON format** based **ONLY** on the Wikipedia data provided.
Pay special attention to capturing detailed information on:
- Challenges, risks, and barriers faced by the industry.
- Market size, growth trends, and any numerical data available.
- Detailed information on major companies, including historical context and notable events (e.g., acquisitions).

Please ensure that the descriptions in the "Market Size and Growth Potential" section are as long and descriptive as possible, and include all available details from the source.

### **Report Structure**
{
  "Industry Overview": {
    "Significance": "<Explain the industry's significance and economic role>",
    "Historical Development": "<Discuss historical development and transformation over time>",
    "Global Differences": "<Provide insights into global vs. regional differences>"
  },
  "Key Trends": [
    {
      "Trend": "<Trend name>",
      "Description": "<Trend description>"
    },
    ... (at least 2-4 items)
  ],
  "Challenges": {
    "Risks And Barriers": "<Identify key risks and barriers (economic, regulatory, operational)>",
    "Addressing Issues": "<Describe how companies are addressing these issues>"
  },
  "Market Size and Growth Potential": {
    "Market Size": "<Provide a detailed description including any numerical data available>",
    "Growth Trends": "<Provide a detailed analysis of historical growth trends and future projections>"
  },
  "Major Companies": {
    "companies": [
      "<List 2-5 leading companies along with a brief note on their market influence, innovations, and historical context>"
    ]
  },
  "Conclusion": {
    "Industry Outlook": "<Summarize the industry outlook>",
    "Future Opportunities": "<Highlight future opportunities and key developments>"
  }
}

### **Important Rules**
- Remove any section with no meaningful data.
- The final report must be **less than 600 words**.
- Ensure structured JSON output enclosed in triple backticks with the label 'json'.
- Do NOT generate new facts beyond the Wikipedia content.
""")

@lru_cache(maxsize=32)
def get_wikipedia_content(industry):
    """
    Retrieves the full Wikipedia page content and URL for the given industry.
    If the direct query fails or is ambiguous, it tries alternative queries
    (appending 'industry' if necessary, and finally using Wikipedia's search function).
    Uses caching to avoid duplicate requests.
    """
    try:
        page = wikipedia.page(industry)
    except (wikipedia.exceptions.PageError, wikipedia.exceptions.DisambiguationError):
        alt_query = industry
        if "industry" not in industry.lower():
            alt_query = industry + " industry"
        try:
            page = wikipedia.page(alt_query)
        except (wikipedia.exceptions.PageError, wikipedia.exceptions.DisambiguationError):
            search_results = wikipedia.search(industry)
            if search_results:
                try:
                    page = wikipedia.page(search_results[0])
                except Exception as e:
                    raise ValueError(f"Unable to retrieve a page for '{industry}' using search results: {e}")
            else:
                raise ValueError(f"No Wikipedia page found for '{industry}'.")
    return page.content, page.url

def extract_json_block(text):
    """
    Uses regex to extract a JSON block enclosed in triple backticks with the 'json' label.
    """
    json_pattern = r"```json\s*(\{.*?\})\s*```"
    match = re.search(json_pattern, text, re.DOTALL)
    if match:
        json_str = match.group(1)
        try:
            return json.loads(json_str)
        except json.JSONDecodeError as e:
            raise ValueError(f"JSON parsing failed: {str(e)}")
    else:
        raise ValueError("No JSON block found in the model output.")

def extract_additional_info(wiki_text, keywords):
    """
    Extracts additional information from the Wikipedia text based on provided keywords.
    Returns concatenated sentences containing those keywords.
    """
    sentences = wiki_text.split('.')
    relevant = [s.strip() for s in sentences if any(kw.lower() in s.lower() for kw in keywords)]
    return ". ".join(relevant) + "."

def merge_additional_info(report_json, wiki_text):
    """
    Merges additional extracted information about challenges and market data into the report JSON.
    """
    # Define keywords for challenges and market size.
    challenge_keywords = ["challenge", "risk", "barrier", "obstacle", "problem"]
    market_keywords = ["market size", "growth", "share", "projection", "trend", "dollar", "billion"]

    # Extract additional info.
    extra_challenges = extract_additional_info(wiki_text, challenge_keywords)
    extra_market = extract_additional_info(wiki_text, market_keywords)

    # Merge if the fields are empty or lack detail.
    if not report_json.get("Challenges", {}).get("Risks And Barriers"):
        report_json.setdefault("Challenges", {})["Risks And Barriers"] = extra_challenges
    if not report_json.get("Market Size and Growth Potential", {}).get("Market Size"):
        report_json.setdefault("Market Size and Growth Potential", {})["Market Size"] = extra_market

    return report_json

def clean_text(text):
    """
    Cleans the text by removing specific patterns like numeric ranges with Unicode dashes.
    """
    # Remove patterns like "1974–1984" (digits, en-dash, digits)
    cleaned = re.sub(r'\d+–\d+', '', text)
    return cleaned.strip()

def clean_report(report):
    """
    Recursively cleans all string fields in the report dictionary.
    """
    if isinstance(report, dict):
        return {k: clean_report(v) for k, v in report.items()}
    elif isinstance(report, list):
        return [clean_report(item) for item in report]
    elif isinstance(report, str):
        return clean_text(report)
    else:
        return report

def generate_market_report_gemini(industry):
    """
    Generates a comprehensive market research report for the given industry.
    Combines full Wikipedia data with a detailed prompt and uses Gemini 1.5 Flash.
    Returns a structured JSON report.
    """
    try:
        wiki_content, wiki_url = get_wikipedia_content(industry)
    except ValueError as err:
        return {"error": str(err)}

    # Assemble the final prompt by combining the system prompt with the full Wikipedia data.
    final_prompt = system_prompt_template.template + "\n\nWikipedia Data:\n" + wiki_content

    # Use Gemini 1.5 Flash for content generation.
    model = genai.GenerativeModel("gemini-1.5-flash")
    response = model.generate_content([final_prompt])
    full_text = response.text.strip()

    try:
        report_json = extract_json_block(full_text)
    except ValueError as e:
        return {"error": str(e), "raw_output": full_text}

    # Merge in additional extracted info (e.g., challenges, market data).
    report_json = merge_additional_info(report_json, wiki_content)

    # Add metadata if missing.
    report_json["source_url"] = wiki_url
    report_json["industry"] = industry

    # Clean all text in the report to remove undesired patterns.
    report_json = clean_report(report_json)

    return report_json

# Generate reports for your five chosen industries.
industries = [
    "Automotive",
    "Luxury Fashion",
    "Video Games",
    "Laptop",
    "FMCG in India"
]

all_reports = {}
for ind in industries:
    all_reports[ind] = generate_market_report_gemini(ind)

# Convert the reports dictionary into a formatted JSON string.
json_string = json.dumps(all_reports, indent=4, ensure_ascii=False)

# Print the final JSON outputs for the five chosen industries.
print(json_string)
# Out:
# {
#     "Automotive": {
#         "Industry Overview": {
#             "Significance": "The automotive industry designs, develops, manufactures, markets, and sells motor vehicles, with cars comprising over three-quarters of production.  It plays a significant role in global economies, employing millions and impacting energy consumption, infrastructure development, and societal mobility.",
#             "Historical Development": "Early car development involved steam-powered vehicles (Cugnot, 1769) and internal combustion engines (de Rivaz, 1808).  Carl Benz's 1886 Benz Patent-Motorwagen is considered the first practical, marketable automobile. Mass production, starting with Oldsmobile in 1901 and revolutionized by Ford's moving assembly line in 1913, made cars widely accessible.  The industry experienced rapid technological advancements throughout the 20th century.",
#             "Global Differences": "China is the largest producer and market for cars, followed by the US, Japan, Germany, South Korea, and India.  Car adoption rates vary significantly across regions, with rapid growth in newly industrialized countries like China and India in the 21st century. Europe has led initiatives like the \"Fit for 55\" legislation aiming for zero-emission vehicles by 2035."
#         },
#         "Key Trends": [
#             {
#                 "Trend": "Transition to Electric Vehicles",
#                 "Description": "Electric cars, commercially available since the 2000s, are predicted to become cheaper than petrol cars before 2025, driven by environmental concerns and government regulations.  In 2021, 9% of cars sold were electric, yet they comprised less than 2% of cars on the road."
#             },
#             {
#                 "Trend": "Mass Production and Competition",
#                 "Description": "Mass production techniques, initially pioneered in the US, spread globally, leading to intense competition among manufacturers.  The assembly line revolutionized efficiency and output, but also led to the disappearance of many smaller companies."
#             },
#             {
#                 "Trend": "Increased Vehicle Size and Weight",
#                 "Description": "Cars have increased in weight due to added safety features and technology, influencing fuel consumption and environmental impact. Heavier cars are safer for occupants but present risks to other road users.  Some regions tax heavier vehicles to encourage lighter designs."
#             },
#             {
#                 "Trend": "Autonomous and Shared Vehicles",
#                 "Description": "Autonomous vehicles and car-sharing services are emerging, potentially disrupting traditional car ownership models.  Car-sharing services saw significant growth in the US between 2006 and 2007."
#             }
#         ],
#         "Challenges": {
#             "Risks And Barriers": "Environmental concerns, including air and water pollution, greenhouse gas emissions, and resource depletion, pose significant challenges.  Traffic congestion, road safety, and the social costs of car dependency (including health impacts) are also major issues.  Competition from public transport is increasing.",
#             "Addressing Issues": "Regulations are being implemented to phase out fossil fuel vehicles, promote electric vehicles, and improve fuel efficiency.  Companies are investing in alternative powertrains and materials, while cities are promoting alternative transportation options and implementing congestion mitigation strategies."
#         },
#         "Market Size and Growth Potential": {
#             "Market Size": "Around one billion cars were in use worldwide. In 2020, 56 million cars were manufactured globally, down from 67 million in 2019. China was by far the largest producer (20 million), followed by Japan (7 million).  Cars consume approximately a trillion liters of petrol and diesel annually, consuming about 50 exajoules of energy.",
#             "Growth Trends": "Car usage is increasing rapidly, especially in China and India.  The industry faces the challenge of balancing growth with environmental sustainability. The European Commission's \"Fit for 55\" targets zero-emission vehicles by 2035, representing a significant shift in the market."
#         },
#         "Major Companies": {
#             "companies": [
#                 {
#                     "Company": "Ford",
#                     "Note": "Pioneered the moving assembly line, revolutionizing mass production and making cars affordable. Established international branches early in the 20th century."
#                 },
#                 {
#                     "Company": "General Motors",
#                     "Note": "Established the Companion Make Program, offering a range of car brands to cater to different consumer segments."
#                 },
#                 {
#                     "Company": "Toyota",
#                     "Note": "Started as a loom manufacturer before transitioning to car production, becoming the world's largest automobile manufacturer."
#                 },
#                 {
#                     "Company": "Benz & Cie.",
#                     "Note": "Founded by Carl Benz, who patented the Benz Patent-Motorwagen in 1886, marking the birth of the modern car. Became a significant player in the early automotive industry."
#                 },
#                 {
#                     "Company": "Daimler Motoren Gesellschaft (DMG)",
#                     "Note": "Founded by Gottlieb Daimler and Wilhelm Maybach, it played a crucial role in the development of early automobiles and later merged with Benz & Cie."
#                 }
#             ]
#         },
#         "Conclusion": {
#             "Industry Outlook": "The automotive industry faces a period of significant transformation driven by environmental regulations and technological advancements.  The shift towards electric vehicles and autonomous driving is reshaping the industry landscape.",
#             "Future Opportunities": "Opportunities exist in developing sustainable technologies, improving safety features, enhancing connectivity, and creating innovative mobility solutions such as car-sharing and autonomous driving services."
#         },
#         "source_url": "https://en.wikipedia.org/wiki/Car",
#         "industry": "Automotive"
#     },
#     "Luxury Fashion": {
#         "Industry Overview": {
#             "Significance": "The luxury goods industry encompasses high-value products and services with demand increasing disproportionately to income rises.  It contrasts with necessity goods where demand increases proportionally less than income.",
#             "Historical Development": "The concept of luxury dates back to at least Plato's time. The industry has evolved from bespoke, family-run businesses to mass-produced branded goods by large corporations, with a shift from exclusive distribution to global marketing and online accessibility.",
#             "Global Differences": "The largest luxury markets include the United States, China (surpassing Japan in 2012), and other countries with growing wealthier consumer bases.  Reports predicted East Asia, particularly China, to become the world's largest market."
#         },
#         "Key Trends": [
#             {
#                 "Trend": "Democratization of luxury (Masstige)",
#                 "Description": "Marketing strategies aim to make luxury brands more affordable to a wider consumer base."
#             },
#             {
#                 "Trend": "Globalization",
#                 "Description": "Expanding markets due to increasing wealth in various countries, particularly East Asia."
#             },
#             {
#                 "Trend": "Consolidation",
#                 "Description": "Growth of large companies owning numerous luxury brands across various sectors (e.g., LVMH, Kering, Richemont)."
#             },
#             {
#                 "Trend": "Luxury brand collaborations",
#                 "Description": "Partnerships between luxury brands and other seemingly contrasting brands (e.g., streetwear, celebrities, video games) to attract broader audiences."
#             }
#         ],
#         "Challenges": {
#             "Risks And Barriers": "Maintaining profitability in the mass consumer goods market, navigating cultural diversification challenges, and managing fluctuating demand based on economic conditions (e.g., the 1997 Asian Financial Crisis).",
#             "Addressing Issues": "Companies employ strategies like masstige, globalization, consolidation, and brand collaborations to address these challenges."
#         },
#         "Market Size and Growth Potential": {
#             "Market Size": "In 2000, the global luxury goods market was valued at nearly $170 billion, with the United States as the largest regional market.  Luxury drinks were the largest sector, followed by watches and jewelry, and clothing and accessories. The top ten markets accounted for 83% of sales. By 2012, China surpassed Japan as the world's largest luxury market, accounting for over 25% of the global market.  In 2014, the sector was projected to grow significantly over ten years due to millions of consumers.",
#             "Growth Trends": "The luxury goods market experienced sustained growth for many years, except for setbacks like the 1997 Asian Financial Crisis. Strong growth was seen in 2000 (7.9%).  The watches and jewelry sector showed particularly strong performance (23.3% growth between 1996-2000).  Future growth is anticipated due to a rising number of affluent consumers globally."
#         },
#         "Major Companies": {
#             "companies": [
#                 {
#                     "Company": "LVMH",
#                     "Description": "The largest luxury goods producer globally, with over fifty brands and significant sales (e.g., €42.6 billion in 2017)."
#                 },
#                 {
#                     "Company": "Kering",
#                     "Description": "A major luxury goods conglomerate with substantial revenue and net income (e.g., €15.9 billion revenue, €2.3 billion net income in 2019)."
#                 },
#                 {
#                     "Company": "Richemont",
#                     "Description": "Another significant player in the luxury goods market."
#                 }
#             ]
#         },
#         "Conclusion": {
#             "Industry Outlook": "The luxury goods industry is expected to continue its growth trajectory, driven by globalization and increasing consumer affluence, especially in emerging markets.",
#             "Future Opportunities": "Continued expansion into new markets, innovative marketing strategies (such as brand collaborations), and leveraging technological advancements offer significant future opportunities."
#         },
#         "source_url": "https://en.wikipedia.org/wiki/Luxury_goods",
#         "industry": "Luxury Fashion"
#     },
#     "Video Games": {
#         "Industry Overview": {
#             "Significance": "The video game industry is a major player in the modern entertainment industry, exceeding the global music and film industries in revenue by 2020, and significantly influencing the electronics industry through hardware demands and innovation.",
#             "Historical Development": "Starting with simple prototypes in the 1950s and 1960s, the industry rapidly expanded in the 1970s and 1980s, experiencing a market crash in North America in 1983 due to oversaturation and lack of publishing control.  The industry subsequently matured under the dominance of Japanese companies, establishing practices that continue today. The 2000s saw a focus on \"AAA\" games, while the rise of the internet and digital distribution enabled the growth of independent game development.",
#             "Global Differences": "The industry is led by major companies in North America, Europe, and Southeast Asia.  Regional preferences vary; Japanese consumers favor handheld games, while South Korea and China show a preference for computer games."
#         },
#         "Key Trends": [
#             {
#                 "Trend": "Rise of Mobile Gaming",
#                 "Description": "Smartphones and tablets have made mobile gaming a dominant platform, accounting for 48% of the market in 2020."
#             },
#             {
#                 "Trend": "Growth of Indie Games",
#                 "Description": "Digital distribution facilitated the rise of indie game development, offering an alternative to large-budget \"AAA\" titles."
#             },
#             {
#                 "Trend": "Increasing Monetization",
#                 "Description": "The industry is increasingly incorporating \"games as a service\" models and other methods to generate revenue beyond initial game sales."
#             },
#             {
#                 "Trend": "Esports Growth",
#                 "Description": "Professional esports leagues have grown significantly, contributing to the industry's overall revenue and influence."
#             }
#         ],
#         "Challenges": {
#             "Risks And Barriers": "The industry faces risks from market crashes (as seen in 1983), competition, the need to control game distribution to prevent unlicensed development and oversaturation, and concerns about violence and addiction in video games.",
#             "Addressing Issues": "Console manufacturers like Nintendo implemented measures to control game development and distribution, while the ESRB rating system helps address concerns about violent content. Digital distribution has enabled indie developers to thrive, adding diversity to the market."
#         },
#         "Market Size and Growth Potential": {
#             "Market Size": "In 2020, the global video game market generated an estimated $159 billion in revenue. This revenue is broken down between mobile games (48%), console games (28%), and personal computer games (23%).",
#             "Growth Trends": "The market experienced rapid growth in the 1970s and 1980s, followed by a period of consolidation.  The rise of mobile gaming and digital distribution have driven further growth in recent years.  In 2020, mobile games accounted for nearly half of the global market revenue, showcasing a significant shift in player demographics towards casual gaming and increased monetization."
#         },
#         "Major Companies": {
#             "companies": [
#                 {
#                     "Company": "Nintendo",
#                     "Note": "A key player in revitalizing the industry after the 1983 crash, establishing control over game development and distribution on its platforms."
#                 },
#                 {
#                     "Company": "Sony",
#                     "Note": "Dominant player in the console market, alongside Microsoft's Xbox and Nintendo."
#                 },
#                 {
#                     "Company": "Atari",
#                     "Note": "Early pioneer with arcade games like Pong, significantly impacting the industry's early development."
#                 }
#             ]
#         },
#         "Conclusion": {
#             "Industry Outlook": "The video game industry shows strong growth potential, driven by mobile gaming, indie development, and esports.  However, the industry continues to face challenges regarding content, addiction, and ethical considerations."
#         },
#         "source_url": "https://en.wikipedia.org/wiki/Video_game",
#         "industry": "Video Games"
#     },
#     "Laptop": {
#         "Industry Overview": {
#             "Significance": "The laptop computer industry plays a significant role in the global economy, providing portable personal computing devices for various applications including work, education, and entertainment.",
#             "Historical Development": "Beginning with early prototypes in the 1960s and 70s (Dynabook, IBM SCAMP, IBM 5100), the industry saw rapid growth with the introduction of laptop-sized computers like the Epson HX-20 in 1981.  Key innovations included the touchpad (1983), pointing stick (1992), and advancements in display technology, CPUs (Intel i386SL, Intel SpeedStep, AMD PowerNow!), memory cards (PCMCIA), hard drives, and optical drives.  The industry has seen a continuous evolution in form factors, including convertibles and 2-in-1s, and a shift towards thinner, lighter designs and higher processing power.",
#             "Global Differences": "The provided text does not offer insights into global vs. regional differences in the laptop industry."
#         },
#         "Key Trends": [
#             {
#                 "Trend": "Technological Convergence",
#                 "Description": "Hybrids, convertibles, and 2-in-1 laptops combine features of tablets and laptops, blurring the lines between device categories."
#             },
#             {
#                 "Trend": "Miniaturization and Increased Power",
#                 "Description": "Laptops are becoming smaller and lighter while achieving greater processing power, though high-end desktop CPUs still outperform the fastest laptop processors."
#             },
#             {
#                 "Trend": "Shift Away from Internal Optical Drives",
#                 "Description": "Internal optical drives are disappearing from most laptops due to the prevalence of external peripherals and the focus on thinner designs."
#             },
#             {
#                 "Trend": "Increased RAM and Storage Capacity",
#                 "Description": "Higher RAM capacities (e.g., 16GB and above) are becoming more common, along with the transition from HDDs to faster, more efficient SSDs."
#             }
#         ],
#         "Challenges": {
#             "Risks And Barriers": "Challenges include limited upgradeability compared to desktops due to soldered components, susceptibility to damage from spills, heat generation and cooling issues, and limited battery life. Security and privacy risks associated with theft and webcam misuse are also significant.",
#             "Addressing Issues": "Manufacturers are addressing these issues through improved cooling systems, more durable designs, and enhanced security features such as Activation Lock and biometric authentication.  The use of external keyboards and monitors can mitigate ergonomic issues."
#         },
#         "Market Size and Growth Potential": {
#             "Market Size": "In 2023, an estimated 166 million laptops were sold. In the first quarter of 2024, laptops and detachable tablets comprised about 64% of personal computer sales.  Before 2008, laptops were significantly more expensive than desktops, averaging $1,131 compared to $696 for desktops.  However, prices decreased substantially around 2008 due to low-cost netbooks and further decreased in the 2010s due to inexpensive processors and operating systems, with new laptops available for $299 as of 2023.",
#             "Growth Trends": "The global market share for portable computers grew from 2% in 1986 to exceeding desktop shipments in the third quarter of 2008 (38.6 million vs 38.5 million units). The increasing popularity of laptops is driven by portability, connectivity, and affordability, especially with the advent of tablets and inexpensive models. The convergence of laptop and tablet features is also driving market growth."
#         },
#         "Major Companies": {
#             "companies": [
#                 {
#                     "Company": "Toshiba",
#                     "Note": "Historically a leading vendor, particularly in the 1990s."
#                 },
#                 {
#                     "Company": "Compaq",
#                     "Note": "A major player in the 1990s, later acquired by HP."
#                 },
#                 {
#                     "Company": "HP",
#                     "Note": "Acquired Compaq and became a leading vendor in the 2000s and 2010s."
#                 },
#                 {
#                     "Company": "Dell",
#                     "Note": "Became a significant player in the early 2000s."
#                 },
#                 {
#                     "Company": "Lenovo",
#                     "Note": "Acquired IBM's PC business and emerged as a leading vendor."
#                 }
#             ]
#         },
#         "Conclusion": {
#             "Industry Outlook": "The laptop industry continues to evolve, driven by technological advancements and user demand for portable computing devices. The trend towards convergence with tablets, increased power in smaller form factors, and greater affordability suggests continued growth.",
#             "Future Opportunities": "Future opportunities lie in innovation in design, improved battery technology, enhanced security features, and the development of specialized laptops for diverse applications (e.g., gaming, professional use)."
#         },
#         "source_url": "https://en.wikipedia.org/wiki/Laptop",
#         "industry": "Laptop"
#     },
#     "FMCG in India": {
#         "Industry Overview": {
#             "Significance": "The fast-moving consumer goods (FMCG) industry, also known as the consumer packaged goods (CPG) industry, is responsible for producing, distributing, and marketing fast-moving consumer goods.  In India, it's the fourth largest economic sector.",
#             "Historical Development": "Between 1950 and 1980, investment was limited due to low purchasing power.  The period from 1980 to 1990 saw increased product variety. Post-1991 globalization spurred growth and foreign investment.",
#             "Global Differences": "Unlike the US, where a few large companies dominate, India's FMCG industry is highly fragmented."
#         },
#         "Key Trends": [
#             {
#                 "Trend": "Increased Government Initiatives",
#                 "Description": "Farm loan waivers, Direct Benefit Transfer (DBT), and rural infrastructure development are boosting minimum wages and FMCG demand."
#             },
#             {
#                 "Trend": "Lifestyle and Cultural Changes",
#                 "Description": "Urban areas show a shift towards premium products due to rising middle-class income."
#             },
#             {
#                 "Trend": "Policy and Regulatory Changes",
#                 "Description": "Relaxed licensing rules, FDI allowance in retail, and GST rate reductions are attracting foreign investment and increasing consumption."
#             },
#             {
#                 "Trend": "Rising Advertisement Costs",
#                 "Description": "FMCG companies are increasing advertising expenditure by 10-20% annually to build customer bases and compete."
#             },
#             {
#                 "Trend": "Shift Towards Natural Products",
#                 "Description": "The premium market is increasingly focused on products made entirely from natural ingredients."
#             }
#         ],
#         "Challenges": {
#             "Risks And Barriers": "High initial launch costs due to a fragmented market and intense competition; the need for substantial marketing and advertising investment to gain market share.",
#             "Addressing Issues": "Companies are utilizing promotional deals and combo offers to attract price-sensitive customers and build brand loyalty."
#         },
#         "Market Size and Growth Potential": {
#             "Market Size": "In India, FMCG revenue grew from US$31.6 billion in 2011 to US$52.8 billion in 2017-2018.  Household and personal care products account for 50% of sales, healthcare for 31-32%, and food and beverage for 18-19%.  The rural market holds a 45% revenue share, while the urban market accounts for 55%. Over 65% of Indians live in rural areas, spending about 50% of their expenditure on FMCG products.  Online FMCG purchases are projected to reach 850 million by 2025.",
#             "Growth Trends": "Revenue grew at a 21.4% rate over 10 years.  A 27.9% CAGR is projected, reaching US$103.7 billion by 2020. The rural market is projected to grow at a 14.6% CAGR, reaching US$100 billion by 2020 and US$220 billion by 2025. Growth is driven by increased working women, disposable income, purchasing power, online shopping awareness, brand consciousness, changing preferences, and government policies."
#         },
#         "Major Companies": {
#             "companies": []
#         },
#         "Conclusion": {
#             "Industry Outlook": "The Indian FMCG industry shows strong growth potential driven by economic factors, policy changes, and evolving consumer preferences.",
#             "Future Opportunities": "Growth in the rural market, expansion of online sales, and the increasing demand for premium and natural products offer significant opportunities."
#         },
#         "source_url": "https://en.wikipedia.org/wiki/FMCG_in_India",
#         "industry": "FMCG in India"
#     }
# }
